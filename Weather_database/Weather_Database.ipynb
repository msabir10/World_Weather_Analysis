# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import time
import gmaps
import datetime as dt
from scipy.stats import linregress
import matplotlib.pyplot as plt


# Import API key
from config import weather_api_key


# Incorporated citipy to determine city based on latitude and longitude
#install from command line before opening jupyter notebook as 'pip install citipy'
from citipy import citipy


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 584

# %%
#create url for query with imperial units and city at the end
#url from https://openweathermap.org/appid
url = "http://api.openweathermap.org/data/2.5/weather?id=524901"
unit = "imperial"
query_url = f"{url}&appid={weather_api_key}&units={unit}&q="

# Lists for results
lat = []
lng = []
city_name = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
current_description = []
date = []
country = []

# %%
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        current_description.append(response['weather'][0]['description'])
        date.append(response["dt"])
        country.append(response["sys"]["country"])
        city_name.append(city)
        print(f"City processed: {city}")
    except:
        print(f"City NOT found: {city}")
# Out:
# City processed: flin flon
# City processed: rikitea
# City processed: atuona
# City processed: saint-ambroise
# City processed: moron
# City processed: xichang
# City processed: jamestown
# City NOT found: taolanaro
# City processed: sibolga
# City processed: makushino
# City processed: zhezkazgan
# City processed: yulara
# City processed: tiksi
# City processed: taoudenni
# City processed: avarua
# City processed: bluff
# City processed: tasiilaq
# City processed: ribeira grande
# City processed: clyde river
# City processed: evanston
# City NOT found: mentok
# City processed: luau
# City NOT found: mys shmidta
# City processed: punta arenas
# City processed: sobolevo
# City processed: cape town
# City processed: amapa
# City processed: longyearbyen
# City processed: esperance
# City processed: ushuaia
# City processed: barrow
# City processed: butaritari
# City processed: guilin
# City processed: hofn
# City processed: codrington
# City NOT found: samusu
# City NOT found: illoqqortoormiut
# City processed: tuensang
# City processed: vaini
# City processed: richards bay
# City processed: hasaki
# City processed: wanning
# City processed: nelson bay
# City processed: lakatoro
# City processed: mosjoen
# City processed: georgetown
# City processed: egvekinot
# City processed: provideniya
# City processed: vanimo
# City processed: albany
# City processed: thompson
# City processed: mar del plata
# City processed: saint george
# City processed: geraldton
# City processed: mataura
# City processed: puerto ayora
# City processed: sur
# City processed: faanui
# City NOT found: nizhneyansk
# City processed: marsa matruh
# City processed: nouadhibou
# City processed: hilo
# City processed: hermanus
# City NOT found: belushya guba
# City processed: assens
# City processed: mahibadhoo
# City processed: arraial do cabo
# City processed: carnarvon
# City processed: bimbo
# City NOT found: sentyabrskiy
# City processed: hithadhoo
# City processed: fereydun kenar
# City processed: ossora
# City processed: kahului
# City processed: wana
# City processed: pyay
# City NOT found: dzhusaly
# City processed: cabo san lucas
# City processed: flinders
# City processed: ponta do sol
# City processed: kieta
# City processed: muros
# City processed: chistogorskiy
# City processed: malibu
# City processed: pacific grove
# City processed: sharhorod
# City processed: ilulissat
# City processed: svetlaya
# City processed: namibe
# City processed: port hardy
# City processed: lampang
# City processed: hobyo
# City processed: san patricio
# City processed: mecca
# City processed: mount gambier
# City processed: busselton
# City processed: oskarshamn
# City processed: tevaitoa
# City processed: kaeo
# City processed: lorengau
# City NOT found: vaitupu
# City processed: kozhva
# City processed: cidreira
# City processed: madhogarh
# City processed: gopalpur
# City processed: iralaya
# City processed: formosa do rio preto
# City processed: qaanaaq
# City processed: upernavik
# City processed: mirante do paranapanema
# City processed: emporia
# City processed: aitape
# City processed: new norfolk
# City processed: east london
# City processed: jasper
# City processed: bako
# City processed: ostrovnoy
# City processed: mugumu
# City processed: guaymas
# City processed: asau
# City processed: lebu
# City processed: odweyne
# City processed: camacha
# City processed: victoria
# City NOT found: attawapiskat
# City processed: dikson
# City processed: mahebourg
# City processed: smithers
# City processed: san quintin
# City processed: tazmalt
# City processed: yellowknife
# City processed: souillac
# City processed: kruisfontein
# City NOT found: umzimvubu
# City processed: kapaa
# City processed: rudnya
# City processed: ieper
# City processed: chokurdakh
# City processed: casambalangan
# City processed: hamilton
# City processed: komsomolskiy
# City processed: natal
# City processed: bud
# City processed: alyangula
# City processed: birnin kebbi
# City processed: hanumangarh
# City processed: la ronge
# City processed: caravelas
# City processed: hobart
# City processed: tuktoyaktuk
# City processed: dzhubga
# City processed: qaqortoq
# City processed: bambous virieux
# City processed: ballachulish
# City processed: najran
# City processed: porto novo
# City processed: aklavik
# City processed: port alfred
# City processed: luderitz
# City NOT found: louisbourg
# City processed: burnie
# City processed: cherrapunji
# City processed: sorland
# City processed: bredasdorp
# City processed: sorgun
# City NOT found: fort saint john
# City processed: vestmannaeyjar
# City processed: sitka
# City processed: manta
# City processed: saint-augustin
# City processed: tucuman
# City processed: baruun-urt
# City processed: batagay-alyta
# City processed: quatre cocos
# City processed: kimbe
# City processed: cherskiy
# City processed: mareeba
# City processed: orchard homes
# City processed: itaperucu
# City processed: mackenzie
# City processed: tautira
# City processed: krasnoselkup
# City processed: pimentel
# City processed: alpena
# City processed: igarka
# City processed: nizhniy kuranakh
# City processed: goderich
# City processed: stryn
# City processed: izvestkovyy
# City processed: galesong
# City processed: sagua la grande
# City NOT found: barentsburg
# City processed: tefe
# City processed: hudson bay
# City NOT found: grand river south east
# City processed: lagoa
# City processed: ravar
# City processed: stephenville
# City processed: guerrero negro
# City processed: xacmaz
# City processed: salalah
# City processed: kaitangata
# City processed: castro
# City processed: itarema
# City processed: lompoc
# City processed: galatas
# City processed: shakiso
# City processed: lavrentiya
# City processed: talnakh
# City processed: zhuhai
# City NOT found: nguiu
# City processed: grindavik
# City processed: bukachacha
# City processed: broken hill
# City processed: kamenka
# City processed: alofi
# City processed: acheng
# City NOT found: ust-bolsheretsk
# City processed: meulaboh
# City processed: sioux lookout
# City NOT found: mrirt
# City processed: rundu
# City processed: skjervoy
# City processed: nanortalik
# City processed: phatthalung
# City processed: marawi
# City processed: wuwei
# City processed: dangriga
# City processed: kudahuvadhoo
# City processed: kirakira
# City processed: imeni poliny osipenko
# City processed: fortuna
# City processed: touros
# City processed: saldanha
# City processed: rio gallegos
# City processed: tual
# City processed: kupang
# City processed: olafsvik
# City processed: sychevka
# City processed: rovinj
# City processed: constitucion
# City processed: karachi
# City processed: ancud
# City processed: egyek
# City processed: kamen-rybolov
# City processed: coahuayana
# City processed: luleburgaz
# City processed: bulungu
# City processed: havoysund
# City processed: morehead
# City processed: herne bay
# City processed: khatanga
# City processed: antofagasta
# City NOT found: rungata
# City processed: manoel urbano
# City processed: menongue
# City processed: gao
# City processed: tolaga bay
# City NOT found: bossembele
# City processed: kaiu
# City processed: kununurra
# City processed: nsawam
# City processed: sovetskiy
# City processed: sakakah
# City processed: arlit
# City processed: garmsar
# City processed: amga
# City processed: mantua
# City processed: moses lake
# City processed: sunbury
# City processed: kavieng
# City processed: saint anthony
# City processed: mayo
# City processed: tacna
# City processed: mao
# City processed: naze
# City processed: araouane
# City processed: port hedland
# City processed: nuuk
# City processed: raudeberg
# City processed: kaka
# City processed: benavente
# City processed: iqaluit
# City processed: klaksvik
# City processed: kita
# City NOT found: gurgan
# City processed: kodiak
# City processed: chuy
# City processed: saint-joseph
# City processed: waitati
# City processed: airai
# City NOT found: bokspits
# City processed: viseu
# City processed: xining
# City processed: garowe
# City processed: sarishabari
# City processed: mitu
# City processed: brae
# City processed: ballina
# City processed: bathsheba
# City NOT found: tsihombe
# City processed: nemuro
# City processed: olinda
# City processed: chinsali
# City NOT found: ozgon
# City NOT found: amderma
# City processed: wanlaweyn
# City processed: villanueva de la serena
# City processed: manadhoo
# City processed: puerto penasco
# City processed: nikolskoye
# City processed: ambilobe
# City processed: zhanaozen
# City processed: nyurba
# City processed: dunedin
# City processed: sao filipe
# City processed: akdepe
# City processed: bethel
# City processed: mehamn
# City processed: teya
# City processed: derzhavinsk
# City processed: mandalgovi
# City processed: yamada
# City processed: acquaviva
# City processed: saint-philippe
# City processed: narsaq
# City processed: banff
# City processed: port elizabeth
# City processed: westport
# City processed: baykit
# City processed: kabalo
# City processed: visby
# City processed: goma
# City processed: calama
# City processed: moyale
# City NOT found: kamenskoye
# City processed: pevek
# City processed: katsuura
# City processed: severo-kurilsk
# City processed: sola
# City processed: nokaneng
# City processed: cap malheureux
# City processed: leningradskiy
# City processed: tsuyama
# City processed: lhokseumawe
# City processed: atasu
# City processed: lucapa
# City processed: sao joao do piaui
# City processed: bol
# City processed: kailua
# City processed: kendrapara
# City processed: mandya
# City processed: matara
# City processed: togur
# City processed: poum
# City processed: kangaatsiaq
# City processed: hambantota
# City processed: iranshahr
# City processed: rosario oeste
# City processed: potoru
# City NOT found: marcona
# City processed: saskylakh
# City processed: dudinka
# City processed: kaura namoda
# City processed: santa cruz de la palma
# City processed: nicholasville
# City processed: melfi
# City processed: svetlogorsk
# City processed: avera
# City processed: oxford
# City processed: comodoro rivadavia
# City processed: okhotsk
# City processed: yaan
# City processed: kuttigen
# City processed: krasnyy chikoy
# City processed: tulun
# City processed: tambovka
# City processed: waipawa
# City processed: sabang
# City processed: dingle
# City processed: anloga
# City processed: sambava
# City processed: san jose de las lajas
# City processed: jaumave
# City processed: cukai
# City processed: englehart
# City processed: roma
# City processed: yar-sale
# City processed: lakhdenpokhya
# City processed: toora-khem
# City processed: port lincoln
# City processed: teluknaga
# City processed: poronaysk
# City processed: norman wells
# City processed: lerwick
# City processed: birin
# City processed: kushima
# City processed: luanda
# City processed: hokitika
# City processed: cascais
# City processed: tigil
# City processed: do gonbadan
# City processed: mola di bari
# City NOT found: athgarh
# City processed: oranjemund
# City processed: pustoshka
# City processed: san carlos
# City processed: miguel auza
# City processed: ahipara
# City processed: baykalsk
# City processed: buala
# City processed: greensboro
# City processed: koslan
# City processed: tukrah
# City processed: stockach
# City processed: isla vista
# City processed: empoli
# City processed: salta
# City NOT found: keshan
# City processed: montrose
# City processed: pangoa
# City processed: elk city
# City processed: paamiut
# City processed: san cristobal
# City processed: port blair
# City processed: lake city
# City processed: bengkulu
# City processed: nome
# City processed: tecoanapa
# City processed: celestun
# City processed: anadyr
# City processed: biak
# City processed: northam
# City processed: fairbanks
# City processed: beyneu
# City processed: bara
# City NOT found: kerteh
# City processed: vila velha
# City processed: vao
# City processed: epe
# City processed: waw
# City processed: christchurch
# City processed: lovozero
# City processed: ust-nera
# City processed: shestakovo
# City NOT found: bur gabo
# City processed: okha
# City processed: cabra
# City processed: bilibino
# City processed: black river
# City processed: aksu
# City processed: jishou
# City processed: esso
# City processed: halifax
# City NOT found: barroualie
# City NOT found: bargal
# City processed: escanaba
# City processed: belaya gora
# City NOT found: aflu
# City processed: beringovskiy
# City processed: katherine
# City processed: canto do buriti
# City processed: cockburn town
# City processed: te anau
# City processed: atherton
# City processed: mildura
# City processed: sivaki
# City processed: dhidhdhoo
# City processed: boa vista
# City NOT found: barbar
# City processed: concepcion del uruguay
# City processed: rocha
# City NOT found: lolua
# City processed: noumea
# City processed: turukhansk
# City processed: arona
# City processed: amazar
# City NOT found: karaul
# City processed: kyzyl-suu
# City NOT found: talah
# City processed: makakilo city
# City processed: komatipoort
# City processed: deputatskiy
# City processed: merauke
# City NOT found: westpunt
# City processed: bantry
# City NOT found: okandja
# City processed: santa rosa
# City processed: atar
# City processed: eureka
# City NOT found: burica
# City NOT found: labutta
# City processed: parrita
# City processed: marzuq
# City processed: abu dhabi
# City processed: henties bay
# City processed: hualmay
# City processed: singapore
# City processed: vung tau
# City NOT found: dien bien
# City processed: saint-denis
# City processed: sao joao da barra
# City processed: cururupu
# City processed: tuatapere
# City processed: lady frere
# City processed: kurilsk
# City processed: bonthe
# City processed: severodvinsk
# City processed: berlevag
# City processed: mogadishu
# City processed: myitkyina
# City processed: verkhnevilyuysk
# City processed: kabinda
# City processed: bonavista
# City processed: tabou
# City processed: chapaevsk
# City processed: cabedelo
# City processed: columbus
# City processed: izhma
# City processed: choma
# City processed: gizo
# City processed: mokhotlong
# City processed: simao
# City processed: ischia
# City processed: kiama
# City NOT found: samalaeulu
# City processed: la rochelle
# City processed: aberdeen
# City processed: aswan
# City processed: merritt
# City processed: bandarbeyla
# City processed: sabha
# City processed: wanxian
# City processed: high level
# City processed: magalia
# City processed: rosarito
# City processed: pochutla
# City processed: chicama
# City processed: buraydah
# City processed: srednekolymsk
# City processed: lichinga
# City processed: samfya
# City processed: sinnamary
# City processed: cap-aux-meules
# City processed: uarini
# City processed: langarud
# City processed: mount isa
# City processed: nizwa
# City processed: half moon bay
# City processed: kargasok
# City processed: bairiki
# City processed: torbay
# City processed: shar
# City processed: khandyga
# City processed: morant bay
# City processed: nioro
# City processed: port arthur
# City processed: andenes
# City processed: ternate
# City processed: biskamzha
# City processed: estevan
# City NOT found: halalo
# City processed: saint-leu
# City processed: santiago de cuba
# City processed: qinhuangdao
# City processed: phek
# City processed: puerto del rosario
# City processed: moshupa
# City processed: les cayes
# City processed: tecuala
# City processed: hwange
# City processed: castro verde
# City processed: kalemie
# City processed: storforshei
# City processed: otavi
# City processed: ishigaki
# City processed: surt
# City processed: gazipur
# City processed: tabas
# City processed: adrar
# City processed: mackay
# City NOT found: zolotinka
# City processed: dehloran
# City processed: thanh hoa

# %%
#build a data frame's titles
city_data = {
    "City": city_name,
    "Country":country,
    "Date":date, 
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness":cloudiness, 
    "Wind Speed":wind_speed,
    "Current Description":current_description
}
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country        Date      Lat       Lng  Max Temp  Humidity  \
# 0       flin flon      CA  1635270917  54.7682 -101.8650     39.04        93
# 1         rikitea      PF  1635270596 -23.1203 -134.9692     75.11        79
# 2          atuona      PF  1635270604  -9.8000 -139.0333     77.29        68
# 3  saint-ambroise      CA  1635270714  48.5501  -71.3324     55.94        46
# 4           moron      AR  1635270917 -34.6534  -58.6198     98.02        23
# 5         xichang      CN  1635270918  27.8964  102.2634     55.40        79
# 6       jamestown      US  1635270603  42.0970  -79.2353     44.19        99
# 7         sibolga      ID  1635270918   1.7427   98.7792     75.92        94
# 8       makushino      RU  1635270919  55.2103   67.2442     29.62        65
# 9      zhezkazgan      KZ  1635270919  47.8043   67.7144     41.13        60
#
#    Cloudiness  Wind Speed Current Description
# 0          90        8.05                mist
# 1         100       18.75          light rain
# 2          61       15.90       broken clouds
# 3         100        3.44     overcast clouds
# 4          14        1.01          few clouds
# 5          94        2.37     overcast clouds
# 6          90        7.00                mist
# 7         100        0.72     overcast clouds
# 8          16        9.60          few clouds
# 9         100       14.97     overcast clouds

# %%
# Save data frame to CSV
city_data_df.to_csv('weatherpy_database.csv')
