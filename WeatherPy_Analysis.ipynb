# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import time
import gmaps
import datetime as dt
from scipy.stats import linregress
import matplotlib.pyplot as plt


# Import API key
from config import weather_api_key
from config import g_key

# Incorporated citipy to determine city based on latitude and longitude
#install from command line before opening jupyter notebook as 'pip install citipy'
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %%
#create url for query with imperial units and city at the end
#url from https://openweathermap.org/appid
url = "http://api.openweathermap.org/data/2.5/weather?id=524901"
unit = "imperial"
query_url = f"{url}&appid={weather_api_key}&units={unit}&q="

# Lists for results
lat = []
lng = []
city_name = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
date = []
country = []

# %%
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        date.append(response["dt"])
        country.append(response["sys"]["country"])
        city_name.append(city)
        print(f"City processed: {city}")
    except:
        print(f"City NOT found: {city}")
# Out:
# City processed: cabo san lucas
# City processed: ambon
# City processed: watsa
# City processed: barrow
# City processed: bluff
# City NOT found: marcona
# City processed: ushuaia
# City processed: kapaa
# City processed: saint-augustin
# City processed: ribeira grande
# City processed: kahului
# City processed: hermanus
# City processed: rock springs
# City processed: rikitea
# City processed: krasnogorsk
# City processed: mahebourg
# City processed: imbituba
# City processed: lompoc
# City processed: albany
# City processed: rudnichnyy
# City processed: vilhena
# City processed: khatanga
# City processed: cape town
# City processed: east london
# City processed: makungu
# City NOT found: cheyur
# City processed: walvis bay
# City processed: blagoyevo
# City processed: chuy
# City processed: ponta do sol
# City processed: mercedes
# City processed: hithadhoo
# City processed: cherskiy
# City processed: hobart
# City NOT found: belushya guba
# City processed: port hedland
# City processed: yellowknife
# City processed: sorland
# City processed: isangel
# City processed: port lincoln
# City processed: tasiilaq
# City processed: busselton
# City processed: burriana
# City processed: mataura
# City processed: taltal
# City processed: atuona
# City processed: kodiak
# City processed: torbay
# City processed: caborca
# City NOT found: vaitupu
# City processed: mabaruma
# City processed: qaanaaq
# City processed: butaritari
# City processed: ponta delgada
# City NOT found: mutsamudu
# City processed: tiksi
# City processed: jamestown
# City processed: grao mogol
# City processed: vaini
# City processed: punta alta
# City processed: bloomfield
# City NOT found: grand river south east
# City NOT found: cumaribo
# City NOT found: jiddah
# City processed: kodinsk
# City processed: andenes
# City NOT found: illoqqortoormiut
# City processed: puerto ayora
# City processed: geraldton
# City NOT found: palabuhanratu
# City processed: pampa
# City processed: tokoroa
# City processed: georgetown
# City processed: tingi
# City processed: bethel
# City processed: isakly
# City processed: bambanglipuro
# City processed: akhtanizovskaya
# City processed: carnarvon
# City processed: port alfred
# City processed: thompson
# City processed: mbandaka
# City processed: talnakh
# City processed: mayumba
# City processed: vila franca do campo
# City processed: bandarbeyla
# City processed: bilma
# City processed: rawson
# City processed: kirakira
# City processed: leningradskiy
# City processed: cururupu
# City processed: saint george
# City processed: yaan
# City processed: anshun
# City processed: castro
# City processed: nizhnyaya salda
# City processed: henties bay
# City processed: panjab
# City processed: ati
# City NOT found: taolanaro
# City processed: jasper
# City processed: chicama
# City NOT found: umzimvubu
# City processed: jardim
# City processed: tuatapere
# City processed: canalete
# City processed: gorontalo
# City processed: guilin
# City processed: atar
# City processed: lekoni
# City NOT found: barentsburg
# City processed: barkly west
# City processed: upernavik
# City processed: victoria
# City processed: kutum
# City processed: galesong
# City processed: ilulissat
# City processed: punta arenas
# City processed: dikson
# City processed: joao pinheiro
# City processed: margate
# City processed: mar del plata
# City processed: lahaina
# City NOT found: tsihombe
# City processed: bardiyah
# City processed: saldanha
# City processed: sept-iles
# City processed: cayenne
# City processed: garmsar
# City processed: christchurch
# City processed: chokurdakh
# City processed: bambous virieux
# City processed: nata
# City NOT found: bur gabo
# City processed: longyearbyen
# City NOT found: samusu
# City processed: nikolskoye
# City processed: tazovskiy
# City processed: bathsheba
# City processed: chegdomyn
# City processed: viedma
# City processed: emerald
# City processed: iracoubo
# City processed: lubango
# City processed: avarua
# City processed: trincomalee
# City processed: bilibino
# City processed: yelkhovka
# City processed: hervey bay
# City processed: katsuura
# City processed: kishanganj
# City processed: zhuhai
# City processed: san vicente
# City processed: la roche-sur-yon
# City processed: yerbogachen
# City processed: laguna
# City processed: broome
# City processed: poum
# City processed: rio grande
# City processed: mallaig
# City processed: samarai
# City processed: maragogi
# City processed: baykit
# City processed: monte plata
# City processed: pisco
# City processed: bonthe
# City processed: faro
# City processed: maldonado
# City processed: aniva
# City processed: kalevala
# City processed: fomboni
# City processed: touros
# City processed: nuuk
# City processed: hauterive
# City processed: itoman
# City processed: camacupa
# City processed: goderich
# City NOT found: saleaula
# City processed: cidreira
# City NOT found: rawannawi
# City processed: makakilo city
# City processed: kyzyl-suu
# City processed: susanville
# City processed: lata
# City processed: port elizabeth
# City processed: kamaishi
# City processed: new norfolk
# City processed: arraial do cabo
# City processed: fort nelson
# City processed: general roca
# City processed: clyde river
# City processed: jumla
# City processed: westport
# City processed: vrangel
# City processed: terney
# City processed: the valley
# City processed: yuksekova
# City processed: lake city
# City processed: sur
# City processed: hamilton
# City processed: pochutla
# City processed: tooele
# City processed: yarmouth
# City processed: iqaluit
# City processed: san patricio
# City processed: grindavik
# City processed: cabedelo
# City processed: kobayashi
# City processed: airai
# City processed: ambanja
# City processed: marzuq
# City NOT found: amderma
# City NOT found: nizhneyansk
# City processed: abha
# City processed: wankaner
# City processed: dunmore east
# City processed: rayevskiy
# City processed: sao filipe
# City processed: leshukonskoye
# City processed: torbeyevo
# City processed: aksu
# City processed: raudeberg
# City processed: puerto ayacucho
# City processed: la ronge
# City processed: bengkulu
# City processed: narsaq
# City processed: vostok
# City processed: cabinda
# City processed: souillac
# City processed: kaitangata
# City processed: huanimaro
# City processed: sibu
# City processed: sirnak
# City processed: saskylakh
# City processed: ravar
# City processed: santa fe
# City processed: vega de alatorre
# City processed: inirida
# City processed: abu dhabi
# City processed: santa catarina de tepehuanes
# City processed: kamloops
# City processed: plouzane
# City processed: aden
# City processed: lebu
# City processed: vanimo
# City processed: sambava
# City processed: marataizes
# City processed: abu zabad
# City processed: fortuna
# City processed: gushi
# City processed: tuktoyaktuk
# City processed: pangnirtung
# City processed: bredasdorp
# City NOT found: attawapiskat
# City processed: pamplona
# City processed: itarema
# City NOT found: galiwinku
# City processed: norman wells
# City processed: uberlandia
# City processed: burnie
# City processed: chiredzi
# City processed: coquimbo
# City processed: fairbanks
# City processed: boa vista
# City processed: shimoda
# City processed: alta floresta
# City processed: nanortalik
# City processed: komsomolskiy
# City processed: northport
# City processed: saucillo
# City processed: carballo
# City processed: plettenberg bay
# City processed: skvyra
# City processed: rocha
# City processed: northam
# City processed: hungund
# City processed: crossville
# City processed: cilegon
# City processed: kuzhorskaya
# City processed: huarmey
# City processed: kysyl-syr
# City processed: hofn
# City NOT found: tuggurt
# City processed: sibolga
# City processed: kaeo
# City processed: staryy nadym
# City processed: bell ville
# City NOT found: skalistyy
# City NOT found: haibowan
# City processed: port hardy
# City processed: kurumkan
# City processed: sisimiut
# City processed: oranjemund
# City processed: develi
# City processed: sioux lookout
# City processed: champasak
# City processed: ustka
# City processed: san quintin
# City processed: muros
# City NOT found: mys shmidta
# City processed: tiarei
# City processed: jieshi
# City processed: braedstrup
# City NOT found: chagda
# City processed: beringovskiy
# City processed: carutapera
# City processed: gazli
# City processed: gotsu
# City processed: porto belo
# City processed: abu kamal
# City processed: vila velha
# City processed: caravelas
# City processed: valparaiso
# City processed: suileng
# City processed: saint-francois
# City processed: provideniya
# City processed: berlevag
# City processed: mbini
# City processed: am timan
# City processed: chunoyar
# City processed: pevek
# City processed: balkanabat
# City NOT found: hihifo
# City NOT found: aflu
# City processed: lagoa
# City processed: weligama
# City processed: petropavlovsk-kamchatskiy
# City processed: paris
# City processed: ambilobe
# City processed: bintulu
# City processed: katima mulilo
# City processed: nouakchott
# City processed: hilo
# City processed: hambantota
# City processed: goundam
# City processed: winnemucca
# City processed: ancud
# City processed: krasnyy yar
# City processed: ucluelet
# City processed: manokwari
# City processed: grand gaube
# City processed: kavaratti
# City processed: oktyabrskoye
# City processed: furstenfeld
# City processed: garowe
# City processed: texarkana
# City processed: port macquarie
# City processed: esperance
# City processed: belyy yar
# City processed: ambulu
# City processed: odweyne
# City processed: juneau
# City processed: xai-xai
# City NOT found: zlatoustovsk
# City processed: maba
# City processed: liverpool
# City processed: kozhevnikovo
# City processed: palafrugell
# City processed: saint-marc
# City processed: vagur
# City processed: acajutla
# City processed: piacabucu
# City processed: nemuro
# City processed: altay
# City processed: mirnyy
# City processed: high level
# City processed: kamenka
# City processed: tilichiki
# City processed: curup
# City processed: kalmunai
# City processed: finschhafen
# City processed: dwarka
# City processed: zdvinsk
# City processed: mount isa
# City processed: ostersund
# City processed: whitianga
# City processed: majdanpek
# City processed: lakes entrance
# City processed: nargana
# City processed: guerrero negro
# City processed: zabaykalsk
# City processed: sosnovo-ozerskoye
# City processed: eyl
# City processed: santo tomas
# City processed: ust-omchug
# City NOT found: labutta
# City processed: bull savanna
# City processed: jiangyou
# City processed: ust-tsilma
# City processed: sao joao da barra
# City processed: luderitz
# City processed: kota bahru
# City processed: forssa
# City processed: safaga
# City processed: perur
# City processed: goulburn
# City processed: svetlogorsk
# City processed: hasaki
# City processed: seminole
# City processed: tura
# City processed: antalaha
# City processed: shelburne
# City processed: salinopolis
# City processed: lucapa
# City processed: daru
# City processed: iralaya
# City processed: buloh kasap
# City processed: kijang
# City processed: verkhnevilyuysk
# City NOT found: louisbourg
# City processed: kabanjahe
# City processed: tungor
# City processed: aklavik
# City processed: saint-philippe
# City processed: el alto
# City processed: adrar
# City NOT found: bolungarvik
# City processed: buta
# City processed: wagar
# City processed: los llanos de aridane
# City processed: ahipara
# City processed: clarksburg
# City processed: dagda
# City processed: jambusar
# City processed: mosquera
# City processed: kruisfontein
# City processed: timbiqui
# City processed: emmett
# City processed: zhanaozen
# City processed: crixas
# City processed: puerto palomas
# City processed: harper
# City NOT found: ngukurr
# City processed: araouane
# City processed: graaff-reinet
# City processed: ndjole
# City processed: husavik
# City processed: igrim
# City processed: port-cartier
# City processed: dalvik
# City processed: kyle
# City processed: waterloo
# City processed: jinchang
# City processed: lingao
# City processed: sitka
# City processed: muzhi
# City processed: klyuchi
# City NOT found: tidore
# City processed: langsa
# City processed: yingcheng
# City processed: faanui
# City NOT found: sorvag
# City NOT found: karkaralinsk
# City processed: grabouw
# City NOT found: kesennuma
# City processed: savannah bight
# City NOT found: rungata
# City processed: mount gambier
# City processed: whitehorse
# City processed: naze
# City processed: evensk
# City processed: caidian
# City processed: codrington
# City processed: chenzhou
# City processed: presidencia roque saenz pena
# City processed: boyolangu
# City processed: san cristobal
# City processed: srednekolymsk
# City processed: manggar
# City processed: severo-kurilsk
# City processed: zhoucheng
# City processed: odenton
# City NOT found: wahran
# City processed: la seyne-sur-mer
# City NOT found: kuche
# City processed: lampang
# City processed: calixtlahuaca
# City processed: bosaso
# City processed: sukhobezvodnoye
# City NOT found: talawdi
# City processed: pasighat
# City processed: pingliang
# City processed: montenegro
# City processed: tezu
# City processed: lorengau
# City processed: demirci
# City processed: bannu
# City processed: luwingu
# City processed: galle
# City processed: pueblo
# City processed: brighton
# City processed: dudinka
# City processed: kappeln
# City processed: dunedin
# City processed: shenjiamen
# City processed: san rafael
# City processed: freeport
# City NOT found: utiroa
# City processed: sheffield
# City processed: urumqi
# City processed: ondjiva
# City processed: kimbe
# City processed: coswig
# City processed: hualmay
# City processed: maun
# City processed: custodia
# City NOT found: tabiauea
# City processed: marawi
# City processed: qaqortoq
# City processed: san-pedro
# City processed: pringsewu
# City processed: ca mau
# City processed: pionerskiy
# City processed: antofagasta
# City processed: russell
# City processed: komarikhinskiy
# City processed: hinton
# City processed: mandal
# City processed: roberval
# City processed: manta
# City processed: bozhou
# City processed: czersk
# City processed: japura
# City processed: yar-sale
# City processed: broken hill
# City processed: tabas
# City processed: jiuquan
# City processed: mae sai
# City processed: progreso
# City processed: kuytun
# City processed: rio gallegos
# City processed: alofi
# City processed: aconibe
# City processed: pangody
# City processed: porto nacional
# City processed: cockburn town
# City processed: college
# City processed: hirson
# City processed: mujiayingzi
# City processed: harnosand
# City processed: zhigansk
# City processed: acapulco
# City processed: san ramon
# City processed: menongue
# City processed: san pedro de macoris
# City processed: corrales
# City processed: padang
# City processed: tautira
# City processed: saint anthony
# City NOT found: koboldo
# City processed: santiago
# City processed: beyneu
# City processed: barceloneta
# City processed: ippy
# City processed: faya
# City processed: karatau
# City processed: khuzhir
# City processed: dingle
# City processed: kavieng
# City processed: xinzhou
# City processed: shakhtinsk
# City processed: luanda
# City processed: calabaca
# City processed: igarka
# City processed: baryshivka
# City processed: andapa
# City NOT found: lolua
# City processed: kuching
# City processed: ballina
# City processed: izumo
# City processed: malanje
# City processed: kingaroy
# City processed: tezontepec
# City processed: sobolevo
# City processed: sao luiz gonzaga
# City processed: sola
# City processed: tavda
# City processed: gornopravdinsk
# City processed: paamiut
# City processed: korla
# City processed: vardo
# City processed: tanout
# City processed: vanderhoof
# City processed: kichera
# City processed: le vauclin
# City processed: nyagan
# City processed: brae
# City processed: dawei
# City processed: senno
# City processed: mumford
# City processed: amapa
# City processed: great yarmouth
# City processed: buinsk
# City processed: jibuti
# City processed: dhidhdhoo
# City processed: karratha
# City processed: spornoye
# City processed: alencon
# City processed: asau
# City processed: port said
# City processed: ostrovnoy
# City processed: morant bay
# City processed: ulladulla
# City processed: cabadiangan
# City processed: blanes
# City NOT found: toliary
# City processed: khandyga
# City processed: vilyuysk
# City processed: roebourne
# City processed: porto novo
# City processed: nisia floresta
# City processed: kyzyl
# City processed: kasongo-lunda
# City processed: mehamn
# City processed: horsham
# City processed: floresti
# City processed: upata
# City processed: kaniama
# City processed: aleksandriyskaya
# City processed: tinley park
# City processed: agara
# City processed: zhongxing
# City processed: inhambane

# %%
#build a data frame's titles
city_data = {
    "City": city_name,
    "Country":country,
    "Date":date, 
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness":cloudiness, 
    "Wind Speed":wind_speed
}
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country        Date      Lat       Lng  Max Temp  Humidity  \
# 0  cabo san lucas      MX  1635214359  22.8909 -109.9124     81.05        71
# 1           ambon      ID  1635214359  -3.6954  128.1814     87.94        74
# 2           watsa      CD  1635214359   3.0372   29.5355     64.89        94
# 3          barrow      US  1635214359  71.2906 -156.7887     24.82        86
# 4           bluff      NZ  1635214360 -46.6000  168.3333     53.94        87
# 5         ushuaia      AR  1635214231 -54.8000  -68.3000     33.46        93
# 6           kapaa      US  1635214360  22.0752 -159.3190     84.18        82
# 7  saint-augustin      CA  1635214360  51.2260  -58.6502     37.44        71
# 8  ribeira grande      PT  1635214361  38.5167  -28.7000     68.99        75
# 9         kahului      US  1635214361  20.8947 -156.4700     82.42        72
#
#    Cloudiness  Wind Speed
# 0           1        5.01
# 1          40        4.61
# 2          94        1.86
# 3          90       14.97
# 4          99       11.18
# 5          40       11.50
# 6          90        4.00
# 7          49        8.48
# 8          24       21.09
# 9          20       23.02

# %%
# Save data frame to CSV
city_data_df.to_csv('Output_data/city_data.csv')

# %%
#add today's date in to charts
date = dt.date.today().strftime("%m/%d/%Y")

plt.scatter(city_data["Lat"], city_data["Max Temp"], marker="o",s=20,alpha=.5, edgecolors="k")
plt.title(f"City Latitude vs. Max Temperature {date}")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Output_data/City Latitude vs Max Temperature.png")
plt.show()

# %%
plt.scatter(city_data["Lat"], city_data["Humidity"], marker="o", s=20,alpha=.5, edgecolors="k")
plt.title(f"City Latitude vs. Humidity {date}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Output_data/City Latitude vs Humidity.png")
plt.show()

# %%
plt.scatter(city_data["Lat"], city_data["Cloudiness"], marker="o", s=20,alpha=.5, edgecolors="k")
plt.title(f"City Latitude vs. Cloudiness {date}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Output_data/City Latitude vs Cloudiness.png")
plt.show()

# %%
plt.scatter(city_data["Lat"], city_data["Wind Speed"], marker="o", s=20,alpha=.5, edgecolors="k")
plt.title(f"City Latitude vs. Wind Speed {date}")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Output_data/City Latitude vs Wind Speed.png")
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                       for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(40,10))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))

# %%
gmaps.configure(api_key=g_key)

# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)
fig.add_layer(heat_layer) 
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=cloudiness, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels

# %%
len(hotels["results"])

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
 # Grab the first hotel from the results and store the name.
try:
    hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
except (IndexError):
    print("Hotel not found... skipping.")

# %%
hotel_df

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
